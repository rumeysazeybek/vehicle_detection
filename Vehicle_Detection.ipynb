# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 115.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LnWvANydkR1HdXkSyXcS")
project = rf.workspace("datasets-xd3z8").project("final_detection-wagxz")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#   Using cached roboflow-1.1.66-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 135.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# Model başlat: küçük, hızlı modelle başla
model = YOLO("yolov8n.yaml")  # daha iyisi için: yolov8s.yaml, yolov8m.yaml

# Eğitimi başlat
model.train(
    data="/content/Final_Detection-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    lr0=0.0005,
    patience=10,  # early stopping için
    name="last_model",
    project="/content/yolo_train"
)
# Out:
# Ultralytics 8.3.154 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install deep_sort_realtime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 120.5 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade ultralytics opencv-python

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
from collections import defaultdict

# RENK TANIMLARI (BGR)
BOX_COLORS = {
    'car': (0, 255, 0),
    'bus': (0, 0, 255),
    'ev': (255, 0, 0),
    'motorbike': (255, 255, 0),
    'truck': (255, 0, 255),
}

# ANA ARAÇ SAYMA FONKSİYONU
def count_vehicles(model_path, video_path, output_video_path, output_csv_path):
    model = YOLO(model_path)
    tracker = DeepSort(max_age=30)
    counted_ids = set()
    class_counts = defaultdict(int)
    vehicle_classes = ['bus', 'car', 'ev', 'motorbike', 'truck']

    cap = cv2.VideoCapture(video_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = model.predict(source=frame, conf=0.4, iou=0.5, classes=[0, 1, 2, 3], verbose=False)[0]

        detections = []
        for box in results.boxes:
            cls_id = int(box.cls[0])
            conf = float(box.conf[0])
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            class_name = model.names[cls_id]
            if class_name in vehicle_classes:
                detections.append(([x1, y1, x2 - x1, y2 - y1], conf, vehicle_classes.index(class_name)))

        tracks = tracker.update_tracks(detections, frame=frame)

        for track in tracks:
            if not track.is_confirmed():
                continue

            track_id = track.track_id
            cls_id = track.get_det_class()
            class_name = vehicle_classes[cls_id]

            if track_id not in counted_ids:
                counted_ids.add(track_id)
                class_counts[class_name] += 1

            l, t, r, b = map(int, track.to_ltrb())
            color = BOX_COLORS.get(class_name, (255, 255, 255))
            cv2.rectangle(frame, (l, t), (r, b), color, 2)
            cv2.putText(frame, f"{class_name} #{track_id}", (l, t - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        # EKRANA SAYIM BİLGİSİ
        y0 = 30
        for i, cls in enumerate(vehicle_classes):
            text = f"{cls}: {class_counts[cls]}"
            cv2.putText(frame, text, (10, y0 + i * 25), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (200, 200, 200), 2)

        out.write(frame)

    cap.release()
    out.release()

    df = pd.DataFrame(class_counts.items(), columns=["class", "count"])
    df.to_csv(output_csv_path, index=False)

    return output_video_path, output_csv_path
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# ✅ GİRİŞ / ÇIKIŞ DOSYALARI
model_path = "/content/drive/MyDrive/dosya/best.pt"  # kendi model dosyan
video_path = "/content/drive/MyDrive/dosya/20250423134715_013752AA.MP4"       # video yolu
output_video = "/content/output_annotated1.mp4"
output_csv = "/content/vehicle_counts.csv"

# ✅ FONKSİYONU ÇALIŞTIR
print("🚗 Sayım başlatıldı...")
video_out, csv_out = count_vehicles(model_path, video_path, output_video, output_csv)
print(f"✅ Sayım tamamlandı.\n📹 Video: {video_out}\n📄 CSV: {csv_out}")
# Out:
# 🚗 Sayım başlatıldı...
# ✅ Sayım tamamlandı.
# 📹 Video: /content/output_annotated1.mp4
# 📄 CSV: /content/vehicle_counts.csv

# %%
from ultralytics import YOLO
import cv2
from deep_sort_realtime.deepsort_tracker import DeepSort
from collections import defaultdict
import pandas as pd

# MODELİ YÜKLE
model = YOLO("/content/yolo_train/last_model/weights/best.pt")  # eğittiğin model

# VİDEO GİRİŞ / ÇIKIŞ
video_path = "/content/drive/MyDrive/dataset/togg10.mp4"
cap = cv2.VideoCapture(video_path)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("/content/output_annotated.mp4", fourcc, fps, (width, height))

# TAKİP SİSTEMİ
tracker = DeepSort(max_age=30)
counted_ids = set()
class_counts = defaultdict(int)
vehicle_classes = ['bus', 'car', 'ev', 'motorbike', 'truck']  # model.names sırasına göre

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # TAHMİN
    results = model.predict(source=frame, conf=0.4, iou=0.5, classes=[0, 1, 2, 3], verbose=False)[0]

    detections = []
    for box in results.boxes:
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        if model.names[cls_id] in vehicle_classes:
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls_id))

    # TAKİP GÜNCELLE
    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        cls_id = track.get_det_class()
        class_name = vehicle_classes[cls_id]

        if track_id not in counted_ids:
            counted_ids.add(track_id)
            class_counts[class_name] += 1

        l, t, r, b = map(int, track.to_ltrb())
        cv2.rectangle(frame, (l, t), (r, b), (0, 255, 0), 2)
        cv2.putText(frame, f"{class_name} #{track_id}", (l, t - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # GERÇEK ZAMANLI SAYIM GÖSTER
    y0 = 30
    for i, cls in enumerate(vehicle_classes):
        text = f"{cls}: {class_counts[cls]}"
        cv2.putText(frame, text, (10, y0 + i * 25), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

    out.write(frame)

cap.release()
out.release()

# SAYIMI CSV'YE YAZ
df = pd.DataFrame(class_counts.items(), columns=["class", "count"])
df.to_csv("/content/vehicle_counts.csv", index=False)

# BİLGİ
print("Sayım tamamlandı. Video: output_annotated.mp4, CSV: vehicle_counts.csv")
# Out:
# ✅ Sayım tamamlandı. Video: output_annotated.mp4, CSV: vehicle_counts.csv
